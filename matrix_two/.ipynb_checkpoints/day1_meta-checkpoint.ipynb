# %%
# ''' Jeśli colab to '''

# GITHUB_TOKEN = ''
# GITHUB_URL = f'https://{GITHUB_TOKEN}@github.com/DranelM/dw_matrix.git'
# !git clone &GITHUB_URL
# !curl -L http://bit.ly/dw_car_data -i car.h5
# Out:
# ' Jeśli colab to '

# %%
import pandas as pd

# %%
df = pd.read_hdf('../data/car.h5')

# %%
df.sample(5)
# Out:
#                                                breadcrumb  \
# 127336  [Osobowe, Peugeot, 308, Peugeot 308 T7 (2008-2...
# 25928   [Osobowe, Volkswagen, Touran, Volkswagen Toura...
# 69682   [Osobowe, Volkswagen, Jetta, Volkswagen Jetta ...
# 109039  [Osobowe, Opel, Vectra, Opel Vectra C (2002-20...
# 99316                     [Osobowe, Volkswagen, Multivan]
#
#                  created_at price_currency               price_details  \
# 127336  16:38, 1 marca 2018            PLN                 Cena Brutto
# 25928   21:59, 4 marca 2018            PLN  Cena Brutto, Do negocjacji
# 69682   09:41, 5 marca 2018            PLN                 Cena Brutto
# 109039  16:39, 2 marca 2018            PLN  Cena Brutto, Do negocjacji
# 99316   14:21, 3 marca 2018            PLN  Cena Brutto, Do negocjacji
#
#         price_value                                     seller_address  \
# 127336      25900.0  Harcerska 67 - 09-400 Płock, Mazowieckie (Polska)
# 25928       16600.0              Szydłowiec, szydłowiecki, Mazowieckie
# 69682       76999.0    ul. Portowa 2 - 44-100 Gliwice, Łabędy (Polska)
# 109039      10800.0                    Warszawa, Mazowieckie, Targówek
# 99316       57999.0  Morzyczyn, ul. Szczecińska 2 b - 73-108 Morzyc...
#
#                        seller_name     seller_type  \
# 127336  F.H.U. JC LIDER AUTO KOMIS          Dealer
# 25928                         None  Osoba prywatna
# 69682               Lellek Gliwice          Dealer
# 109039                        None  Osoba prywatna
# 99316   AUTO HANDEL ''TWINS CARS''          Dealer
#
#         feature_czujniki-parkowania-przednie  \
# 127336                                  True
# 25928                                  False
# 69682                                   True
# 109039                                  True
# 99316                                   True
#
#         feature_poduszka-powietrzna-chroniąca-kolana  ...  param_pearl  \
# 127336                                         False  ...         None
# 25928                                          False  ...         None
# 69682                                          False  ...         None
# 109039                                         False  ...         None
# 99316                                          False  ...         None
#
#         param_stan    param_wersja  param_emisja-co2  param_body-type  \
# 127336     Używane  T7 (2008-2013)              None             None
# 25928      Używane   I (2003-2010)              None             None
# 69682         Nowe      A6 (2010-)              None             None
# 109039     Używane   C (2002-2008)              None             None
# 99316      Używane            None              None             None
#
#         param_matowy  param_bezwypadkowy  param_akryl-(niemetalizowany)  \
# 127336          None                 Tak                           None
# 25928           None                 Tak                           None
# 69682           None                 Tak                           None
# 109039          None                None                           None
# 99316           None                 Tak                           None
#
#         param_monthly-payment-value  car_id
# 127336                         None  127336
# 25928                          None   25928
# 69682                          None   69682
# 109039                         None  109039
# 99316                          None   99316
#
# [5 rows x 155 columns]
